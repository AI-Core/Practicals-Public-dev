# %%
from collections import deque

double_ended_queue = deque([2,3,8,12,10,4,3])
print(double_ended_queue)
double_ended_queue.popleft()
print(double_ended_queue)
double_ended_queue.pop()
print(double_ended_queue)
# Out:
# deque([2, 3, 8, 12, 10, 4, 3])
# deque([3, 8, 12, 10, 4, 3])
# deque([3, 8, 12, 10, 4])

# %%
# Initailising the linked list class

class LinkedList:
    def __init__(self):
        # Initialise the Linked List with the empty head
        self.head = None

class Node:
    def __init__(self, x):
        # A node has two values it's pointer to the next node and it's value
        self.val = x
        self.next = None

# %%
# Adding the linked list representation and node representation

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def __repr__(self):
        # Return the data in the node
        return self.data

class LinkedList:
    def __init__(self):
        self.head = None

    def __repr__(self):
        node = self.head
        nodes = []
        # while there are still nodes to add
        while node is not None:
            # add the node to our list of nodes
            nodes.append(node.data)
            # Go to the next node
            node = node.next
        # Finally add None to the end of the list for the last node 
        nodes.append("None")
        # Return the list with arrows between each node pointing to the next.
        return " -> ".join(nodes)

linked_list = LinkedList() # Right now, linked list is empty.

first_node = Node('a') # Now, 'a' is the first node in our linked list.
linked_list.head = first_node
print(linked_list)
second_node = Node('b') # 'b' is the second node in our linked list.
third_node = Node('c') # 'c' is the third node in our linked list.
first_node.next = second_node  # 'a' is linked to 'b'.
second_node.next = third_node # 'b' is linked to 'c'.
print(linked_list)
# Out:
# a -> None
# a -> b -> c -> None

# %%
# Adding the linked list representation and node representation

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def __repr__(self):
        # Return the data in the node
        return self.data

class LinkedList:
    def __init__(self, nodes=None):
        self.head = None
        if nodes is not None:
            node = Node(data=nodes.pop(0))
            self.head = node
            for elem in nodes:
                node.next = Node(data=elem)
                node = node.next

    def __repr__(self):
        node = self.head
        nodes = []
        # while there are still nodes to add
        while node is not None:
            # add the node to our list of nodes
            nodes.append(node.data)
            # Go to the next node
            node = node.next
        # Finally add None to the end of the list for the last node 
        nodes.append("None")
        # Return the list with arrows between each node pointing to the next.
        return " -> ".join(nodes)

    def __iter__(self):
        node = self.head
         # if node is None, that means that we have reached the end of the linked list
        while node is not None:
            # return the current node and point to the next.
            yield node
            node = node.next

linked_list = LinkedList(['a', 'b', 'c', 'd'])
linked_list
# Out:
# a -> b -> c -> d -> None

# %%
# Adding the linked list representation and node representation

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def __repr__(self):
        # Return the data in the node
        return self.data

class LinkedList:
    def __init__(self, nodes=None):
        self.head = None
        if nodes is not None:
            node = Node(data=nodes.pop(0))
            self.head = node
            for elem in nodes:
                node.next = Node(data=elem)
                node = node.next

    def __repr__(self):
        node = self.head
        nodes = []
        # while there are still nodes to add
        while node is not None:
            # add the node to our list of nodes
            nodes.append(node.data)
            # Go to the next node
            node = node.next
        # Finally add None to the end of the list for the last node 
        nodes.append("None")
        # Return the list with arrows between each node pointing to the next.
        return " -> ".join(nodes)

    def __iter__(self):
        node = self.head
         # if node is None, that means that we have reached the end of the linked list
        while node is not None:
            # return the current node and point to the next.
            yield node
            node = node.next
            
    def add_at_end(self, node: str):
        if self.head is None:
            self.head = Node(data=node)
            return
        for current_node in self:
            pass
        
        current_node.next = Node(data=node)

linked_list = LinkedList(['a', 'b', 'c', 'd'])
print(linked_list)
linked_list.add_at_end('e')
print(linked_list)
# Out:
# a -> b -> c -> d -> None
# a -> b -> c -> d -> e -> None

# %%
# Adding the linked list representation and node representation

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def __repr__(self):
        # Return the data in the node
        return self.data

class LinkedList:
    def __init__(self, nodes=None):
        self.head = None
        if nodes is not None:
            node = Node(data=nodes.pop(0))
            self.head = node
            for elem in nodes:
                node.next = Node(data=elem)
                node = node.next

    def __repr__(self):
        node = self.head
        nodes = []
        # while there are still nodes to add
        while node is not None:
            # add the node to our list of nodes
            nodes.append(node.data)
            # Go to the next node
            node = node.next
        # Finally add None to the end of the list for the last node 
        nodes.append("None")
        # Return the list with arrows between each node pointing to the next.
        return " -> ".join(nodes)

    def __iter__(self):
        node = self.head
         # if node is None, that means that we have reached the end of the linked list
        while node is not None:
            # return the current node and point to the next.
            yield node
            node = node.next
            
    def add_at_end(self, node: str):
        if self.head is None:
            self.head = Node(data=node)
            return
        for current_node in self:
            pass
        
        current_node.next = Node(data=node)

    def add_at_beginning(self, node: str):
        prev_head = self.head
        self.head = Node(data=node)
        self.head.next = prev_head

        
linked_list = LinkedList(['a', 'b', 'c', 'd'])
print(linked_list)
linked_list.add_at_beginning('e')
print(linked_list)
# Out:
# a -> b -> c -> d -> None
# e -> a -> b -> c -> d -> None

# %%
# Adding the linked list representation and node representation

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def __repr__(self):
        # Return the data in the node
        return self.data

class LinkedList:
    def __init__(self, nodes=None):
        self.head = None
        if nodes is not None:
            node = Node(data=nodes.pop(0))
            self.head = node
            for elem in nodes:
                node.next = Node(data=elem)
                node = node.next

    def __repr__(self):
        node = self.head
        nodes = []
        # while there are still nodes to add
        while node is not None:
            # add the node to our list of nodes
            nodes.append(node.data)
            # Go to the next node
            node = node.next
        # Finally add None to the end of the list for the last node 
        nodes.append("None")
        # Return the list with arrows between each node pointing to the next.
        return " -> ".join(nodes)

    def __iter__(self):
        node = self.head
         # if node is None, that means that we have reached the end of the linked list
        while node is not None:
            # return the current node and point to the next.
            yield node
            node = node.next
            
    def add_at_end(self, node: str):
        if self.head is None:
            self.head = Node(data=node)
            return
        for current_node in self:
            pass
        
        current_node.next = Node(data=node)

    def add_at_beginning(self, node: str):
        prev_head = self.head
        self.head = Node(data=node)
        self.head.next = prev_head

    def add_after(self, node: str, new_node: str):
        if self.head is None:
            raise Exception("List is empty")
        
        new_node = Node(data=new_node)
        
        for current_node in self:
            if current_node.data == node:
                new_node.next = current_node.next
                current_node.next = new_node
                return
        raise Exception("Node not found")

        
linked_list = LinkedList(['a', 'b', 'c', 'd'])
print(linked_list)
linked_list.add_after('b', 'e')
print(linked_list)
# Out:
# a -> b -> c -> d -> None
# a -> b -> e -> c -> d -> None

# %%
# Adding the linked list representation and node representation

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def __repr__(self):
        # Return the data in the node
        return self.data

class LinkedList:
    def __init__(self, nodes=None):
        self.head = None
        if nodes is not None:
            node = Node(data=nodes.pop(0))
            self.head = node
            for elem in nodes:
                node.next = Node(data=elem)
                node = node.next

    def __repr__(self):
        node = self.head
        nodes = []
        # while there are still nodes to add
        while node is not None:
            # add the node to our list of nodes
            nodes.append(node.data)
            # Go to the next node
            node = node.next
        # Finally add None to the end of the list for the last node 
        nodes.append("None")
        # Return the list with arrows between each node pointing to the next.
        return " -> ".join(nodes)

    def __iter__(self):
        node = self.head
         # if node is None, that means that we have reached the end of the linked list
        while node is not None:
            # return the current node and point to the next.
            yield node
            node = node.next
            
    def add_at_end(self, node: str):
        if self.head is None:
            self.head = Node(data=node)
            return
        for current_node in self:
            pass
        
        current_node.next = Node(data=node)

    def add_before(self, node: str, new_node: str):
        if self.head is None:
            raise Exception("List is empty")

        if self.head.data == node:
            self.add_at_beginning(new_node)
            return

        new_node = Node(data=new_node)
        prev_node = self.head
        for current_node in self:
            if current_node.data == node:
                prev_node.next = new_node
                new_node.next = current_node
                return
            prev_node = current_node

        raise Exception("Node not found")

        
linked_list = LinkedList(['a', 'b', 'c', 'd'])
print(linked_list)
linked_list.add_before('c', 'e')
print(linked_list)
# Out:
# a -> b -> c -> d -> None
# a -> b -> e -> c -> d -> None

# %%
# Adding the linked list representation and node representation

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    def __repr__(self):
        # Return the data in the node
        return self.data

class LinkedList:
    def __init__(self, nodes=None):
        self.head = None
        if nodes is not None:
            node = Node(data=nodes.pop(0))
            self.head = node
            for elem in nodes:
                node.next = Node(data=elem)
                node = node.next

    def __repr__(self):
        node = self.head
        nodes = []
        # while there are still nodes to add
        while node is not None:
            # add the node to our list of nodes
            nodes.append(node.data)
            # Go to the next node
            node = node.next
        # Finally add None to the end of the list for the last node 
        nodes.append("None")
        # Return the list with arrows between each node pointing to the next.
        return " -> ".join(nodes)

    def __iter__(self):
        node = self.head
         # if node is None, that means that we have reached the end of the linked list
        while node is not None:
            # return the current node and point to the next.
            yield node
            node = node.next
            
    def add_at_end(self, node: str):
        if self.head is None:
            self.head = Node(data=node)
            return
        for current_node in self:
            pass
        
        current_node.next = Node(data=node)

    def add_before(self, node: str, new_node: str):
        if self.head is None:
            raise Exception("List is empty")

        if self.head.data == node:
            self.add_at_beginning(new_node)
            return

        new_node = Node(data=new_node)
        prev_node = self.head
        for current_node in self:
            if current_node.data == node:
                prev_node.next = new_node
                new_node.next = current_node
                return
            prev_node = current_node

        raise Exception("Node not found")
    
    def remove_node(self, node: str):
        if self.head is None:
            raise Exception("List is empty")

        #remove if node easily if start of the list
        if self.head.data == node:
            self.head = self.head.next # remove head
            return
        
        prev_node = self.head
        for current_node in self:
            if current_node.data == node:
                prev_node.next = current_node.next
                return
            prev_node = current_node
        
        raise Exception("Node not found")
        
linked_list = LinkedList(['a', 'b', 'c', 'd'])
print(linked_list)
linked_list.remove_node('c')
print(linked_list)
# Out:
# a -> b -> c -> d -> None
# a -> b -> d -> None
